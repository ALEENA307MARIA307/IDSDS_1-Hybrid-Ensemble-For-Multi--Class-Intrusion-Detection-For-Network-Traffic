# %%
import pandas as pd
df_train=pd.read_csv("train.csv")

# %%
# Separate features and target
X_train = df_train.drop(columns=["label"])
y_train = df_train["label"]

# %%
pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in c:\users\aleena\anaconda3\new folder\lib\site-packages (3.1.0)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\aleena\appdata\roaming\python\python312\site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: numpy>=1.25 in c:\users\aleena\anaconda3\new folder\lib\site-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\aleena\anaconda3\new folder\lib\site-packages (from bayesian-optimization) (1.4.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\aleena\anaconda3\new folder\lib\site-packages (from bayesian-optimization) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aleena\anaconda3\new folder\lib\site-packages (from scikit-learn>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aleena\anaconda3\new folder\lib\site-packages (from scikit-learn>=1.0.0->bayesian-optimization) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

# %%
def objective_bo(max_depth, n_estimators, min_samples_split, min_samples_leaf, criterion):
    criterion = 'gini' if criterion < 0.5 else 'entropy'
    clf = ExtraTreesClassifier(
        max_depth=int(max_depth),
        n_estimators=int(n_estimators),
        min_samples_split=int(min_samples_split),
        min_samples_leaf=int(min_samples_leaf),
        criterion=criterion,
        random_state=42
    )
    score = cross_val_score(
        clf, X_train, y_train,
        scoring='accuracy',
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    ).mean()
    return score

pbounds = {
    'max_depth': (5, 60),
    'n_estimators': (30, 100),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 5),
    'criterion': (0, 1)
}

# %%
optimizer = BayesianOptimization(f=objective_bo, pbounds=pbounds, random_state=42)
optimizer.maximize(init_points=30, n_iter=80)

print("Best parameters:", optimizer.max)
# Out:
# |   iter    |  target   | max_depth | n_esti... | min_sa... | min_sa... | criterion |
# -------------------------------------------------------------------------------------
# | 1         | 0.8592855 | 25.599706 | 96.550001 | 7.8559515 | 3.3946339 | 0.1560186 |
# | 2         | 0.7151472 | 13.579698 | 34.065852 | 8.9294091 | 3.4044600 | 0.7080725 |
# | 3         | 0.5620650 | 6.1321471 | 97.893689 | 8.6595411 | 1.8493564 | 0.1818249 |
# | 4         | 0.7440750 | 15.087248 | 51.296957 | 6.1980514 | 2.7277800 | 0.2912291 |
# | 5         | 0.9323784 | 38.651909 | 39.764570 | 4.3371571 | 2.4654473 | 0.4560699 |
# | 6         | 0.9225834 | 48.184677 | 43.977164 | 6.1138755 | 3.3696582 | 0.0464504 |
# | 7         | 0.9058726 | 38.414966 | 41.936688 | 2.5204127 | 4.7955421 | 0.9656320 |
# | 8         | 0.9234151 | 49.461854 | 51.322963 | 2.7813769 | 3.7369321 | 0.4401524 |
# | 9         | 0.6756900 | 11.712102 | 64.662383 | 2.2751081 | 4.6372816 | 0.2587799 |
# | 10        | 0.9202173 | 41.438725 | 51.819775 | 6.1605441 | 3.1868411 | 0.1848544 |
# | 11        | 0.9111202 | 58.327154 | 84.259297 | 9.5159915 | 4.5793094 | 0.5978999 |
# | 12        | 0.9626389 | 55.703082 | 36.194475 | 3.5678628 | 1.1809091 | 0.3253303 |
# | 13        | 0.8773265 | 26.377250 | 48.994432 | 8.6299000 | 2.4270133 | 0.2809345 |
# | 14        | 0.9403618 | 34.848284 | 39.864695 | 8.4175758 | 1.2982025 | 0.9868869 |
# | 15        | 0.9096296 | 47.473462 | 43.910097 | 2.0441769 | 4.2618457 | 0.7068573 |
# | 16        | 0.9412469 | 45.095394 | 83.988924 | 2.5923572 | 2.4338629 | 0.1158690 |
# | 50        | 0.9628480 | 60.0      | 37.914464 | 2.0       | 1.0       | 1.0       |
# | 51        | 0.9636626 | 55.894160 | 68.998395 | 2.0       | 1.0       | 1.0       |
# | 52        | 0.9618875 | 44.139930 | 72.951974 | 2.0       | 1.0       | 0.0       |
# | 53        | 0.9634024 | 60.0      | 55.389206 | 2.0       | 1.0       | 1.0       |
# | 54        | 0.9633732 | 48.442237 | 95.308995 | 2.0       | 1.0       | 0.0       |
# | 55        | 0.9608442 | 60.0      | 93.940237 | 6.5845874 | 1.0       | 1.0       |
# | 56        | 0.9605184 | 52.828788 | 84.600408 | 6.2397226 | 1.0       | 1.0       |
# | 57        | 0.9604090 | 52.594835 | 100.0     | 6.9769998 | 1.0       | 0.0       |
# | 58        | 0.9549497 | 51.413834 | 34.842794 | 10.0      | 1.0       | 1.0       |
# | 59        | 0.9634924 | 54.161113 | 59.057388 | 2.0       | 1.0       | 0.0       |
# | 60        | 0.9616856 | 55.156861 | 30.0      | 4.9822885 | 1.0       | 1.0       |
# | 61        | 0.9634389 | 50.123902 | 76.410335 | 2.0       | 1.0       | 1.0       |
# | 62        | 0.9590545 | 60.0      | 36.198038 | 7.3221191 | 1.0       | 0.0       |
# | 63        | 0.9534639 | 38.464381 | 30.0      | 2.0       | 1.0       | 0.0       |
# | 64        | 0.9556768 | 51.524365 | 93.028187 | 10.0      | 1.0       | 1.0       |
# | 65        | 0.9629501 | 60.0      | 83.655473 | 4.7364705 | 1.0       | 0.0       |
# | 66        | 0.9605986 | 45.973812 | 95.543643 | 5.2494471 | 1.0       | 1.0       |
# | 67        | 0.9638085 | 54.352104 | 92.573676 | 3.2457956 | 1.0       | 0.0       |
# | 68        | 0.9633878 | 48.485560 | 89.481240 | 2.0       | 1.0       | 1.0       |
# | 69        | 0.9634924 | 50.533660 | 70.153231 | 2.0       | 1.0       | 0.0       |
# | 70        | 0.9625562 | 56.567120 | 60.943402 | 4.7814161 | 1.0       | 1.0       |
# | 71        | 0.9596381 | 48.295725 | 77.117429 | 6.3139913 | 1.0       | 0.0       |
# | 72        | 0.9627775 | 60.0      | 71.727650 | 4.0236203 | 1.0       | 0.0       |
# | 73        | 0.9631471 | 55.216666 | 32.294670 | 2.0       | 1.0       | 0.0       |
# | 74        | 0.8963937 | 60.0      | 30.0      | 2.0       | 5.0       | 1.0       |
# | 75        | 0.9637404 | 55.094988 | 45.452809 | 2.0       | 1.0       | 0.0       |
# | 76        | 0.9631495 | 52.498361 | 52.194557 | 2.0       | 1.0       | 1.0       |
# | 77        | 0.9604090 | 52.245591 | 69.256639 | 6.8475092 | 1.0       | 1.0       |
# | 78        | 0.9640809 | 55.547757 | 76.813275 | 2.0       | 1.0       | 0.0       |
# | 79        | 0.9633903 | 53.375735 | 39.659123 | 2.0       | 1.0       | 1.0       |
# | 80        | 0.9608126 | 41.195986 | 64.616708 | 2.0       | 1.0       | 1.0       |
# | 81        | 0.9617902 | 47.865435 | 90.092940 | 4.9913590 | 1.0       | 0.0       |
# | 82        | 0.9573961 | 38.416346 | 79.791391 | 2.0       | 1.0       | 1.0       |
# | 83        | 0.9558495 | 60.0      | 55.206621 | 10.0      | 1.0       | 0.0       |
# | 84        | 0.9615835 | 56.141807 | 77.021875 | 5.8427282 | 1.0       | 1.0       |
# | 85        | 0.9639277 | 60.0      | 96.268117 | 2.0       | 1.0       | 1.0       |
# | 86        | 0.9623057 | 48.062032 | 33.735924 | 3.8620322 | 1.0       | 0.0       |
# | 87        | 0.9637477 | 60.0      | 47.248455 | 2.0       | 1.0       | 0.0       |
# | 88        | 0.9628480 | 46.990945 | 58.192834 | 2.0       | 1.0       | 1.0       |
# | 89        | 0.9561437 | 37.117093 | 100.0     | 2.0       | 1.0       | 1.0       |
# | 90        | 0.9633125 | 57.690005 | 40.352020 | 2.0       | 1.0       | 0.0       |
# | 91        | 0.9627580 | 51.034501 | 93.463100 | 4.0065204 | 1.0       | 1.0       |
# | 92        | 0.8976655 | 41.496307 | 100.0     | 2.0       | 5.0       | 1.0       |
# | 93        | 0.9404080 | 36.625702 | 98.063813 | 10.0      | 1.0       | 0.0       |
# | 94        | 0.9461809 | 35.711017 | 90.749963 | 2.0       | 1.0       | 0.0       |
# | 95        | 0.9462490 | 37.533812 | 77.136410 | 10.0      | 1.0       | 1.0       |
# | 96        | 0.9510857 | 40.583505 | 61.467932 | 10.0      | 1.0       | 1.0       |
# | 97        | 0.9552294 | 50.591201 | 51.625638 | 10.0      | 1.0       | 1.0       |
# | 98        | 0.9562531 | 60.0      | 88.126933 | 10.0      | 1.0       | 0.0       |
# | 99        | 0.9609780 | 43.818642 | 30.0      | 2.0       | 1.0       | 1.0       |
# | 100       | 0.9606303 | 45.366795 | 62.896463 | 4.8348358 | 1.0       | 0.0       |
# | 101       | 0.9625003 | 56.017111 | 53.902949 | 4.5349346 | 1.0       | 0.0       |
# | 102       | 0.9641587 | 55.393635 | 100.0     | 2.0       | 1.0       | 0.0       |
# | 103       | 0.9629404 | 60.0      | 95.957840 | 4.0275021 | 1.0       | 0.0       |
# | 104       | 0.9623252 | 50.597501 | 57.677462 | 4.9918302 | 1.0       | 1.0       |
# | 105       | 0.9640444 | 56.021526 | 84.903936 | 2.0       | 1.0       | 0.0       |
# | 106       | 0.9617732 | 60.0      | 32.520210 | 4.1152362 | 1.0       | 1.0       |
# | 107       | 0.9634778 | 57.258068 | 49.719505 | 2.0       | 1.0       | 1.0       |
# | 108       | 0.9636869 | 60.0      | 85.213929 | 2.0       | 1.0       | 1.0       |
# | 109       | 0.9608491 | 54.602860 | 40.752622 | 5.9136933 | 1.0       | 1.0       |
# | 110       | 0.9602242 | 50.117666 | 30.0      | 5.5072438 | 1.0       | 0.0       |
# =====================================================================================
# Best parameters: {'target': 0.9643046470345062, 'params': {'max_depth': 60.0, 'n_estimators': 100.0, 'min_samples_split': 2.0, 'min_samples_leaf': 1.0, 'criterion': 0.0}}

# %%
best_et_BOGP=optimizer.max

# %%
import joblib

# %%
del best_et_BOGP['target']

# %%
best_et_BOGP=best_et_BOGP['params']

# %%
best_et_BOGP['criterion']='gini'

# %%
# Convert numeric parameters to int
best_et_BOGP = {k: int(v) if isinstance(v, (np.integer, np.floating)) else v for k, v in best_et_BOGP.items()}

# %%
best_et_BOGP
# Out:
# {'max_depth': 60,
#  'n_estimators': 100,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'criterion': 'gini'}

# %%
joblib.dump(best_et_BOGP, "best_et_BOGP.pkl")
# Out:
# ['best_et_BOGP.pkl']

# %%
import pandas as pd

# %%
df_train=pd.read_csv("train.csv")
df_test=pd.read_csv("test_f.csv")

# %%
# Separate features and target
X_train = df_train.drop(columns=["label"])
y_train = df_train["label"]
# Separate features and target
X_test = df_test.drop(columns=["label"])
y_test = df_test["label"]

# %%
# %pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in c:\users\aleena\anaconda3\new folder\lib\site-packages (0.2.7)
# Requirement already satisfied: numpy in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (1.13.1)
# Requirement already satisfied: six in c:\users\aleena\appdata\roaming\python\python312\site-packages (from hyperopt) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (3.2.1)
# Requirement already satisfied: future in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (4.66.4)
# Requirement already satisfied: cloudpickle in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (2.2.1)
# Requirement already satisfied: py4j in c:\users\aleena\anaconda3\new folder\lib\site-packages (from hyperopt) (0.10.9.9)
# Requirement already satisfied: colorama in c:\users\aleena\appdata\roaming\python\python312\site-packages (from tqdm->hyperopt) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
# Objective function
def objective(params):
    clf = RandomForestClassifier(
        n_estimators=int(params['n_estimators']),
        max_depth=int(params['max_depth']),
        criterion=params['criterion'],
        random_state=42,
        n_jobs=-1
    )
    score = cross_val_score(clf, X_train, y_train, 
                            scoring='accuracy', 
                            cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
                           ).mean()
    return {'loss': -score, 'status': STATUS_OK}

# %%
# Hyperparameter space 
space = {
    'n_estimators': hp.quniform('n_estimators', 50, 150, 1),
    'max_depth': hp.quniform('max_depth', 5, 30, 1),
    'criterion': hp.choice('criterion', ['gini', 'entropy'])
}

rng=np.random.default_rng(42)
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,  
            trials=trials,
            rstate=rng
            )

print("Best hyperparameters:", best)
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 100/100 [14:06:37<00:00, 507.98s/trial, best loss: -0.9580575347129343]
# Best hyperparameters: {'criterion': 1, 'max_depth': 30.0, 'n_estimators': 148.0}

# %%
import joblib

# %%
best_rf=best

# %%
# Convert numeric parameters to int
best_rf = {k: int(v) if isinstance(v, (np.integer, np.floating)) else v for k, v in best_rf.items()}

# %%
best_rf['criterion']='entropy'

# %%
joblib.dump(best_rf, "best_rf.pkl")
# Out:
# ['best_rf.pkl']
